# %% [markdown]
# # Gathering data

# %% [markdown]
# ### importing libraries

# %%
import pandas as pd 
import numpy as np 
import requests 
from PIL import Image 
from io import BytesIO
import tweepy 
import json 
import os 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline 
# %config Inlinebackend.figure_format='retina'
sns.set_style("dark")

# %%
#Set up tweet API 
consumer_key = "iZUDM7qHeP8KujdnK2viA4IKY"
consumer_secret = "GEzcP0jnzdoUyWSOHAtMX6NGo9TW5A3at8QCn2yQUL8MqodyN9"
access_key = "1430888243063517185-zmWhOaNNfjJ1BZ8GM84uvcH6jF2h3V"
access_secret = "vI8OI4HnXyHCYC1YyFfoLLrjJ2DKrBcaTtWVbGxbiJlu5"

# %%
# Twitter authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)   
auth.set_access_token(access_key, access_secret) 
  
# Creating an API object 
api = tweepy.API(auth)

# %%
hashtag_tweets = tweepy.Cursor(api.search_tweets, q="#WM2022", since="2022-6-1",tweet_mode='extended').items(10)

# %%
tweet_data=[]
for tweet in hashtag_tweets:
    tweet_data.append(tweet)
    text = tweet._json["full_text"]
    print(text)
    #using different attributes
    print(tweet.id)
    print(tweet.favorite_count)
    print(tweet.retweet_count)
    print(tweet.created_at)
# Out:
# Unexpected parameter: since
# RT @KalleKoschinsky: Die Wahl und die Vorbereitungen zur #WM2022  sind eine einzige Katar-Strophe.
#
# Bald ist es soweit und ich bitte nochma…
# 1587129756209881090
# 0
# 17
# 2022-10-31 17:09:55+00:00
# RT @KalleKoschinsky: Die Wahl und die Vorbereitungen zur #WM2022  sind eine einzige Katar-Strophe.
#
# Bald ist es soweit und ich bitte nochma…
# 1587128711819796489
# 0
# 17
# 2022-10-31 17:05:46+00:00
# RT @KalleKoschinsky: Die Wahl und die Vorbereitungen zur #WM2022  sind eine einzige Katar-Strophe.
#
# Bald ist es soweit und ich bitte nochma…
# 1587128189830193156
# 0
# 17
# 2022-10-31 17:03:42+00:00
# RT @KalleKoschinsky: Die Wahl und die Vorbereitungen zur #WM2022  sind eine einzige Katar-Strophe.
#
# Bald ist es soweit und ich bitte nochma…
# 1587128124713713667
# 0
# 17
# 2022-10-31 17:03:27+00:00
# RT @KalleKoschinsky: Die Wahl und die Vorbereitungen zur #WM2022  sind eine einzige Katar-Strophe.
#
# Bald ist es soweit und ich bitte nochma…
# 1587126369170984964
# 0
# 17
# 2022-10-31 16:56:28+00:00

# %%
# Write tweet data to json file
with open('tweet_json.json', mode = 'w') as file:
    #_json property which contains JSON serializable response data. For example:
    json.dump([data._json for data in tweet_data], file)

# %%
#loading the data into a frame 
import codecs
basePath = os.path.dirname(os.path.abspath('tweet_json.json'))
tweet_api=pd.read_json(open('tweet_json.json',mode='r',encoding='utf-8'))

# %%
tweet_api.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2022-10-31 17:09:55+00:00  1587129756209881090  1587129756209881088
# 1 2022-10-31 17:05:46+00:00  1587128711819796489  1587128711819796480
# 2 2022-10-31 17:03:42+00:00  1587128189830193156  1587128189830193152
# 3 2022-10-31 17:03:27+00:00  1587128124713713667  1587128124713713664
# 4 2022-10-31 16:56:28+00:00  1587126369170984964  1587126369170984960
#
#                                            full_text  truncated  \
# 0  RT @KalleKoschinsky: Die Wahl und die Vorberei...      False
# 1  RT @KalleKoschinsky: Die Wahl und die Vorberei...      False
# 2  RT @KalleKoschinsky: Die Wahl und die Vorberei...      False
# 3  RT @KalleKoschinsky: Die Wahl und die Vorberei...      False
# 4  RT @KalleKoschinsky: Die Wahl und die Vorberei...      False
#
#   display_text_range                                           entities  \
# 0           [0, 140]  {'hashtags': [{'text': 'WM2022', 'indices': [5...
# 1           [0, 140]  {'hashtags': [{'text': 'WM2022', 'indices': [5...
# 2           [0, 140]  {'hashtags': [{'text': 'WM2022', 'indices': [5...
# 3           [0, 140]  {'hashtags': [{'text': 'WM2022', 'indices': [5...
# 4           [0, 140]  {'hashtags': [{'text': 'WM2022', 'indices': [5...
#
#                                             metadata  \
# 0  {'iso_language_code': 'de', 'result_type': 're...
# 1  {'iso_language_code': 'de', 'result_type': 're...
# 2  {'iso_language_code': 'de', 'result_type': 're...
# 3  {'iso_language_code': 'de', 'result_type': 're...
# 4  {'iso_language_code': 'de', 'result_type': 're...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1  <a href="http://twitter.com/download/android" ...                    NaN
# 2  <a href="http://twitter.com/download/android" ...                    NaN
# 3  <a href="http://twitter.com/download/android" ...                    NaN
# 4  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
#
#    ...  place  contributors  \
# 0  ...    NaN           NaN
# 1  ...    NaN           NaN
# 2  ...    NaN           NaN
# 3  ...    NaN           NaN
# 4  ...    NaN           NaN
#
#                                     retweeted_status  is_quote_status  \
# 0  {'created_at': 'Mon Oct 31 16:22:01 +0000 2022...            False
# 1  {'created_at': 'Mon Oct 31 16:22:01 +0000 2022...            False
# 2  {'created_at': 'Mon Oct 31 16:22:01 +0000 2022...            False
# 3  {'created_at': 'Mon Oct 31 16:22:01 +0000 2022...            False
# 4  {'created_at': 'Mon Oct 31 16:22:01 +0000 2022...            False
#
#   retweet_count  favorite_count  favorited  retweeted  possibly_sensitive lang
# 0            17               0      False      False               False   de
# 1            17               0      False      False               False   de
# 2            17               0      False      False               False   de
# 3            17               0      False      False               False   de
# 4            17               0      False      False               False   de
#
# [5 rows x 27 columns]

# %%
print(os.getcwd())
# Out:
# /Users/islamabdelrahman/Downloads
